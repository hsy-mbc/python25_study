# %% [markdown]
# <a href="https://colab.research.google.com/github/hsy-mbc/python25_study/blob/%EC%9E%90%EC%97%B0%EC%96%B4%EC%B2%98%EB%A6%AC/LLM_%EC%A0%95%EA%B7%9C%ED%91%9C%ED%98%84%EC%8B%9D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
"""
pip install tensorflow
pip install keras
pip install gensim
pip install scikit-learn
pip install nltk
pip install konlpy
pip install pandas
pip install numpy
pip install matplotlib

pip install kss
pip install konlpy
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re

# %%
r = re.compile("a.c")
r.search("kkk")

# %%
r.search("abc")
# Out:
# <re.Match object; span=(0, 3), match='abc'>

# %%
r = re.compile("ab?c")
r.search("abbc")

# %%
r.search("abc")
# Out:
# <re.Match object; span=(0, 3), match='abc'>

# %%
r.search("ac")
# Out:
# <re.Match object; span=(0, 2), match='ac'>

# %%
r = re.compile("ab*c")
r.search("a")

# %%
r.search("ac")
# Out:
# <re.Match object; span=(0, 2), match='ac'>

# %%
r.search("abc")
# Out:
# <re.Match object; span=(0, 3), match='abc'>

# %%
r.search("abbbbbbbbbbc")
# Out:
# <re.Match object; span=(0, 12), match='abbbbbbbbbbc'>

# %%
r = re.compile("ab+c")
r.search("ac")

# %%
r.search("abc")
# Out:
# <re.Match object; span=(0, 3), match='abc'>

# %%
r.search("abbbbc")
# Out:
# <re.Match object; span=(0, 6), match='abbbbc'>

# %%
r = re.compile("^ab")

# %%
r.search("bbc")

# %%
r.search("abz")
# Out:
# <re.Match object; span=(0, 2), match='ab'>

# %%
r = re.compile("ab{2}c")

r.search("ac")
r.search("abc")
r.search("abbbbbc")

# %%
r.search("abbc")
# Out:
# <re.Match object; span=(0, 4), match='abbc'>

# %%
r = re.compile("ab{2,8}c")

# %%
r.search("abbc")
# Out:
# <re.Match object; span=(0, 4), match='abbc'>

# %%
r.search("abbbbbbbbc")
# Out:
# <re.Match object; span=(0, 10), match='abbbbbbbbc'>

# %%
r = re.compile("a{2,}bc")

r.search("bc")
r.search("aa")

# %%
r.search("aabc")
# Out:
# <re.Match object; span=(0, 4), match='aabc'>

# %%
r.search("aaaaaaaaaaaabc")
# Out:
# <re.Match object; span=(0, 14), match='aaaaaaaaaaaabc'>

# %%
r = re.compile("[abc]")
r.search("zzz")

# %%
r.search("a")
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
r.search("aaaaaaaaa")
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
r.search("baac")
# Out:
# <re.Match object; span=(0, 1), match='b'>

# %%
r = re.compile("[a-z]")

r.search("AAA")
r.search("111")

# %%
r.search("aBC")
# Out:
# <re.Match object; span=(0, 1), match='a'>

# %%
r = re.compile("[^abc]")

r.search("a")
r.search("ab")
r.search("b")

# %%
r.search("d")
# Out:
# <re.Match object; span=(0, 1), match='d'>

# %%
r = re.compile("ab.")
r.match("kkkabc")

# %%
r.search("kkkabc")
# Out:
# <re.Match object; span=(3, 6), match='abc'>

# %%
r.match("abckkk")
# Out:
# <re.Match object; span=(0, 3), match='abc'>

# %%
text = "사과 딸기 수박 메론 바나나"
re.split(" ", text)
# Out:
# ['사과', '딸기', '수박', '메론', '바나나']

# %%
text = """사과
딸기
수박
메론
바나나"""

re.split("\n", text)
# Out:
# ['사과', '딸기', '수박', '메론', '바나나']

# %%
text = "사과+딸기+수박+메론+바나나"

re.split("\+", text)
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\+'
# <>:3: SyntaxWarning: invalid escape sequence '\+'
# /tmp/ipython-input-986661568.py:3: SyntaxWarning: invalid escape sequence '\+'
#   re.split("\+", text)
# ['사과', '딸기', '수박', '메론', '바나나']

# %%
text = """이름 : 김철수
전화번호 : 010 - 1234 - 1234
나이 : 30
성별 : 남"""

re.findall("\d+", text)
# Out:
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# <>:6: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-4172876199.py:6: SyntaxWarning: invalid escape sequence '\d'
#   re.findall("\d+", text)
# ['010', '1234', '1234', '30']

# %%
re.findall("\d+", "문자열입니다.")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-3734271287.py:1: SyntaxWarning: invalid escape sequence '\d'
#   re.findall("\d+", "문자열입니다.")
# []

# %%
text = "Regular expression : A regular expression, regex or regexp[1] (sometimes called a rational expression)[2][3] is, in theoretical computer science and formal language theory, a sequence of characters that define a search pattern."

preprocessed_text = re.sub('[^a-zA-Z]', ' ', text)
print(preprocessed_text)
# Out:
# Regular expression   A regular expression  regex or regexp     sometimes called a rational expression        is  in theoretical computer science and formal language theory  a sequence of characters that define a search pattern

# %%
text = """100 John    PROF
101 James     STUD
102 Mac     STUD"""

# %%
re.split('\s+', text)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-1439998361.py:1: SyntaxWarning: invalid escape sequence '\s'
#   re.split('\s+', text)
# ['100', 'John', 'PROF', '101', 'James', 'STUD', '102', 'Mac', 'STUD']

# %%
re.findall('\d+', text)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipython-input-3341100011.py:1: SyntaxWarning: invalid escape sequence '\d'
#   re.findall('\d+', text)
# ['100', '101', '102']

# %%
re.findall('[A-Z]', text)
# Out:
# ['J', 'P', 'R', 'O', 'F', 'J', 'S', 'T', 'U', 'D', 'M', 'S', 'T', 'U', 'D']

# %%
re.findall('[A-Z]{4}', text)
# Out:
# ['PROF', 'STUD', 'STUD']

# %%
re.findall('[A-Z][a-z]+', text)
# Out:
# ['John', 'James', 'Mac']

# %%
from nltk.tokenize import RegexpTokenizer

text = "Don't be fooled by the dark sounding name, Mr. Jone's Orphanage is as cheery as cheery goes for a pastry shop"

tokenizer1 = RegexpTokenizer("[\w]+")
tokenizer2 = RegexpTokenizer("\s+", gaps=True)

print(tokenizer1.tokenize(text))
print(tokenizer2.tokenize(text))
# Out:
# ['Don', 't', 'be', 'fooled', 'by', 'the', 'dark', 'sounding', 'name', 'Mr', 'Jone', 's', 'Orphanage', 'is', 'as', 'cheery', 'as', 'cheery', 'goes', 'for', 'a', 'pastry', 'shop']
# ["Don't", 'be', 'fooled', 'by', 'the', 'dark', 'sounding', 'name,', 'Mr.', "Jone's", 'Orphanage', 'is', 'as', 'cheery', 'as', 'cheery', 'goes', 'for', 'a', 'pastry', 'shop']
# <>:5: SyntaxWarning: invalid escape sequence '\w'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# <>:5: SyntaxWarning: invalid escape sequence '\w'
# <>:6: SyntaxWarning: invalid escape sequence '\s'
# /tmp/ipython-input-2671260385.py:5: SyntaxWarning: invalid escape sequence '\w'
#   tokenizer1 = RegexpTokenizer("[\w]+")
# /tmp/ipython-input-2671260385.py:6: SyntaxWarning: invalid escape sequence '\s'
#   tokenizer2 = RegexpTokenizer("\s+", gaps=True)
