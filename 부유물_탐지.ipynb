# %% [markdown]
# <a href="https://colab.research.google.com/github/hsy-mbc/python25_study/blob/ai-%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D/%EB%B6%80%EC%9C%A0%EB%AC%BC_%ED%83%90%EC%A7%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 13.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 16.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 78.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 138.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="yLfaN2J7y64R3ktYSCZn")
project = rf.workspace("mbc320hsy").project("flotage-cyqmo")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to flotage-6 in yolov8:: 100%|██████████| 9672/9672 [00:01<00:00, 9242.51it/s]
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from ultralytics import YOLO
import os

# 1. 모델 로드 (YOLOv8 nano 모델)
model = YOLO('yolov8n.pt')

# 2. 데이터셋 YAML 파일 경로 설정
# dataset.location 변수에서 다운로드 경로를 가져옵니다.
data_yaml_path = os.path.join(dataset.location, "data.yaml")

print(f"학습 시작. 데이터셋 경로: {data_yaml_path}")

# 3. 학습 시작 (GPU가 자동으로 사용됩니다)
results = model.train(
    data=data_yaml_path,
    epochs=50,
    imgsz=640,
    name='colab_gpu_test',
    patience=3 # 조기 종료 (10 에포크 동안 성능 향상이 없으면 중단)
    # device=0 옵션은 Colab에서 기본 GPU를 사용하므로 생략 가능
)
# Out:
# ...
# 학습 시작. 데이터셋 경로: /content/flotage-6/data.yaml
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CPU (AMD EPYC 7B12)
# ...
